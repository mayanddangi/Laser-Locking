# %% [markdown]
# ### Import necessary library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading data from .csv file
data = np.genfromtxt('spectroscopy data.csv', delimiter=',')

# %%
plt.plot(data[:,0], data[:,2])
plt.show()

# %%
plt.plot(data[:,0], data[:,3])
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize= (100,50))
plt.plot(data[:,0], data[:,4])
plt.show()

# %%
data4_diff = np.diff(data[0:1000,4])
data4_diff = np.append(data4_diff,[0])

# %%
fig,ax = plt.subplots(1,1,figsize= (100,50))
plt.plot(data4_diff[0:400]*5)
plt.plot(data[0:400,4])
plt.plot(data[0:400,2]/500)
# plt.plot([0]*400)
plt.show()

# %%
# Plotting data
plt.plot(data[0:1000:,0], data[0:1000:,1]*100)
plt.plot(data[0:1000:,0], np.log(data[0:1000:,1]*1000))
plt.show()

# %% [markdown]
# $f'(t) = \displaystyle{\lim_{h \to 0}} \frac{f(t+h)-f(t)}{h}$ </br>
# In discrete form deriviative will be equivalent to $\displaystyle{\frac{f(t+\Delta t) - f(t)}{\Delta t}}$ which is proportional to $f(t+\Delta t) - f(t)$

# %%
signal_diff = np.diff(data[0:1000,1])
signal_diff = np.append(signal_diff,[0])

# %%
# signal_diff[np.abs(signal_diff) <= 0.0015] = 0

# %%
signal_cummulative_sum = np.cumsum(signal_diff)

# %%
signal_diff2 = np.diff(signal_diff)
signal_diff2 = np.append(signal_diff2,[0])

# %%
fig,ax = plt.subplots(1,1,figsize= (100,50))
plt.plot(data[0:1000,0], data[0:1000,1])
# plt.plot(data[0:1000,0], signal_diff**2*1000)
# plt.plot(data[0:1000,0], signal_diff/0.0005-data[0:1000,1])
plt.plot(data[0:1000:,0], [0]*1000)
plt.show()

# %% [markdown]
# ## Filtering low frequency from 1st derviative

# %%
len(np.fft.fft(signal_diff))
# Out:
# 1000

# %%
fft_signal = np.fft.fft(signal_diff)

# %%
fft_signal[100:900] = 0

# %%
# fft_signal[np.abs(fft_signal) <= 0.06] = 0

# %%
fig,ax = plt.subplots(1,1,figsize= (100,50))
plt.plot(np.fft.fft(signal_diff))
# plt.plot(fft_signal)
plt.plot(np.real(np.fft.ifft(fft_signal))*50)
# plt.plot(data[0:1000,1])
plt.plot([0]*1000)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#--------------------------------------------------

# %%
fft_data = np.fft.fft(data[0:1000,1])

# %%
# fft_data[0:100] = 0
# fft_data[900:1000] = 0
fft_data[100:900] = 0

# %%
plt.plot(np.fft.fft(signal_diff))
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
fig,ax = plt.subplots(1,1,figsize= (100,50))
# plt.plot(np.fft.fft(signal_diff))
# plt.plot(fft_data[20:980])
plt.plot(np.real(np.fft.ifft(fft_data))*100)
# plt.plot(data[0:1000,1])
# plt.plot(np.diff(data[0:1000,1])*2000)
# plt.plot([0]*1000)
plt.show()
